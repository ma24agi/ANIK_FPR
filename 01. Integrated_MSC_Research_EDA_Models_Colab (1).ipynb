# %% [markdown]
# # Brain Tumor MRI — File 1 (Xception, EfficientNetB0, ResNet50)
# This notebook is streamlined to train and evaluate only three models: Xception (Baseline), EfficientNetB0, and ResNet50.
# Run the cells from top to bottom. Each model is split into build → train → evaluate.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# =========================
# Imports
# =========================
import os
import random
import time
import gc

import numpy as np
import pandas as pd
import tensorflow as tf

import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras import models
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, array_to_img, load_img

# plot_model (keep same name)
try:
    from tensorflow.keras.utils import plot_model
except Exception:
    from keras.utils import plot_model  # fallback

from IPython.display import display, Image

# Sklearn (for extra graphs)
from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve,
    average_precision_score
)

# %%
# =========================
# Global variables
# =========================
SAVE = False
SEED = 111

# Reproducibility
tf.keras.utils.set_random_seed(SEED)
tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# Optional: stronger determinism (if supported)
try:
    tf.config.experimental.enable_op_determinism()
except Exception:
    pass

# Visualization settings
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = (16, 10)
plt.rcParams.update({'font.size': 14})

# Data Classifications
CLASS_TYPES = ['pituitary', 'notumor', 'meningioma', 'glioma']
N_TYPES = len(CLASS_TYPES)

print("TensorFlow:", tf.__version__)
print("GPU devices:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow: 2.19.0
# GPU devices: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# =========================
# Speed / quality tuning (reduce training time)
# =========================
# Set FAST_MODE=True to train the three transfer-learning models faster on Colab.
# You can switch FAST_MODE=False for higher accuracy (more epochs / heavier augmentation).

FAST_MODE = True

# Mixed precision can significantly speed up training on most Colab GPUs (T4/L4/A100).
USE_MIXED_PRECISION = True

# Input resolution (smaller = faster). 128 is usually a good speed/quality trade-off.
IMAGE_SIZE_FAST = (128, 128)
IMAGE_SIZE_FULL = (150, 150)

# Batch size (bigger = fewer steps/epoch, faster if VRAM allows).
# If you hit OOM on any model, drop BATCH_SIZE_FAST to 32.
BATCH_SIZE_FAST = 64
BATCH_SIZE_FULL = 32

# Data augmentation level (heavy augmentation slows training a lot with ImageDataGenerator).
AUGMENTATION_MODE = 'light' if FAST_MODE else 'full'   # 'light' | 'medium' | 'full'

# Transfer learning training schedule
EPOCHS_HEAD = 4 if FAST_MODE else 12
EPOCHS_FINE = 2 if FAST_MODE else 8
FINE_TUNE = True
FINE_TUNE_FRACTION = 0.10 if FAST_MODE else 0.20

# Learning rates
LR_HEAD = 3e-4 if FAST_MODE else 1e-3
LR_FINE = 1e-4

# Label smoothing can improve generalization with fewer epochs
LABEL_SMOOTHING = 0.05 if FAST_MODE else 0.0

# Early stopping & ReduceLROnPlateau tuning
EARLY_STOP_PATIENCE = 2 if FAST_MODE else 5
REDUCE_LR_PATIENCE = 1 if FAST_MODE else 3

PLOT_EXTRA_GRAPHS = True  # set False to skip ROC/PR curves for faster evaluation

# Apply mixed precision (if enabled)
if USE_MIXED_PRECISION:
    try:
        from tensorflow.keras import mixed_precision
        mixed_precision.set_global_policy('mixed_float16')
        print('Mixed precision policy:', mixed_precision.global_policy())
    except Exception as e:
        print('Mixed precision not enabled:', e)

# Final chosen image_size / batch_size
image_size = IMAGE_SIZE_FAST if FAST_MODE else IMAGE_SIZE_FULL
batch_size = BATCH_SIZE_FAST if FAST_MODE else BATCH_SIZE_FULL

print('FAST_MODE:', FAST_MODE)
print('image_size:', image_size)
print('batch_size:', batch_size)
print('AUGMENTATION_MODE:', AUGMENTATION_MODE)
# Out:
# Mixed precision policy: <DTypePolicy "mixed_float16">
# FAST_MODE: True
# image_size: (128, 128)
# batch_size: 64
# AUGMENTATION_MODE: light

# %%
# =========================
# Dataset Paths
# =========================
# Set USER_PATH to your extracted dataset folder.
# If you used the unzip cell above, USER_PATH should be DATA_ROOT.
DATA_ROOT = "/content/drive/MyDrive/Anik_MSC/Dataset"   # extracted folder
USER_PATH = DATA_ROOT  # <-- Change if your dataset is elsewhere

train_dir = USER_PATH + r'/Training/'
test_dir  = USER_PATH + r'/Testing/'

print("USER_PATH:", USER_PATH)
print("train_dir:", train_dir)
print("test_dir :", test_dir)

# Helpful checks (clear errors if path is wrong)
assert os.path.isdir(train_dir), f"Training folder not found: {train_dir}"
assert os.path.isdir(test_dir),  f"Testing folder not found: {test_dir}"
# Out:
# USER_PATH: /content/drive/MyDrive/Anik_MSC/Dataset
# train_dir: /content/drive/MyDrive/Anik_MSC/Dataset/Training/
# test_dir : /content/drive/MyDrive/Anik_MSC/Dataset/Testing/

# %%
# =========================
# Function for importing data
# =========================
def get_data_labels(directory, shuffle=True, random_state=0):
    """
    Function used for going into the main training directory
    whose directory has sub-class-types.
    """
    from sklearn.utils import shuffle as sk_shuffle
    import os

    data_path = []
    data_labels = []

    for label in os.listdir(directory):
        label_dir = os.path.join(directory, label)

        # Avoid stray files (e.g., .DS_Store)
        if not os.path.isdir(label_dir):
            continue

        for image in os.listdir(label_dir):
            image_path = os.path.join(label_dir, image)
            data_path.append(image_path)
            data_labels.append(label)

    if shuffle:
        data_path, data_labels = sk_shuffle(data_path, data_labels, random_state=random_state)

    return data_path, data_labels

# %%
# =========================
# Getting data using above function
# =========================
train_paths, train_labels = get_data_labels(train_dir)
test_paths, test_labels   = get_data_labels(test_dir)

print('Training')
print(f'Number of Paths: {len(train_paths)}')
print(f'Number of Labels: {len(train_labels)}')
print('\nTesting')
print(f'Number of Paths: {len(test_paths)}')
print(f'Number of Labels: {len(test_labels)}')
# Out:
# Training
# Number of Paths: 5600
# Number of Labels: 5600
#
# Testing
# Number of Paths: 1600
# Number of Labels: 1600

# %%
# =========================
# Dataset distribution visualization
# =========================
_, ax = plt.subplots(ncols=3, figsize=(20, 14))

# Training type counts
class_counts_train = [len([x for x in train_labels if x == label]) for label in CLASS_TYPES]
print('Training Counts')
print(dict(zip(CLASS_TYPES, class_counts_train)))

ax[0].set_title('Training Data')
ax[0].pie(
    class_counts_train,
    labels=[label.title() for label in CLASS_TYPES],
    colors=['#FAC500', '#0BFA00', '#0066FA', '#FA0000'],
    autopct=lambda p: '{:.2f}%\n{:,.0f}'.format(p, p * sum(class_counts_train) / 100),
    explode=tuple(0.01 for _ in range(N_TYPES)),
    textprops={'fontsize': 20}
)

# Train/Test split
ax[1].set_title('Train Test Split')
ax[1].pie(
    [len(train_labels), len(test_labels)],
    labels=['Train', 'Test'],
    colors=['darkcyan', 'orange'],
    autopct=lambda p: '{:.2f}%\n{:,.0f}'.format(p, p * (len(train_labels) + len(test_labels)) / 100),
    explode=(0.1, 0),
    startangle=85,
    textprops={'fontsize': 20}
)

# Testing type counts
class_counts_test = [len([x for x in test_labels if x == label]) for label in CLASS_TYPES]
print('\nTesting Counts')
print(dict(zip(CLASS_TYPES, class_counts_test)))

ax[2].set_title('Testing Data')
ax[2].pie(
    class_counts_test,
    labels=[label.title() for label in CLASS_TYPES],
    colors=['#FAC500', '#0BFA00', '#0066FA', '#FA0000'],
    autopct=lambda p: '{:.2f}%\n{:,.0f}'.format(p, p * sum(class_counts_test) / 100),
    explode=tuple(0.01 for _ in range(N_TYPES)),
    textprops={'fontsize': 20}
)

plt.show()
# Out:
# Training Counts
# {'pituitary': 1400, 'notumor': 1400, 'meningioma': 1400, 'glioma': 1400}
#
# Testing Counts
# {'pituitary': 400, 'notumor': 400, 'meningioma': 400, 'glioma': 400}

# %%
# =========================
# Quick image sanity check
# =========================
im = load_img(train_paths[3], target_size=(150, 150))
im = img_to_array(im)

im = np.expand_dims(im, axis=0)
print(f'x reshaped: {im.shape}')

im /= np.max(im)  # normalization for display
im = array_to_img(im[0])
display(im)
# Out:
# x reshaped: (1, 150, 150, 3)
# <PIL.Image.Image image mode=RGB size=150x150>

# %%
# =========================
# Function to display images by index
# =========================
def show_images(paths, label_paths, index_list=range(10), im_size=250, figsize=(12, 8), save=False):
    """
    Show images from a given path based on the inputted
    list indices related to the desired images one wishes
    to see.
    """
    num_images = len(list(index_list))
    num_rows = (num_images + 3) // 4

    _, ax = plt.subplots(nrows=num_rows, ncols=4, figsize=figsize)
    ax = ax.flatten()

    for i, index in enumerate(index_list):
        if i >= len(ax):
            break

        img = load_img(paths[index], target_size=(im_size, im_size))
        ax[i].imshow(img)
        ax[i].set_title(f'{index}: {label_paths[index]}')
        ax[i].axis('off')

    # Turn off unused axes (if any)
    for j in range(i + 1, len(ax)):
        ax[j].axis('off')

    plt.tight_layout()

    if save:
        plt.savefig('show_image.pdf')
    else:
        plt.show()

# %%
# Four different data classification images, from different angles (images independent)
show_images(
    train_paths, train_labels,
    im_size=350, figsize=(13, 10),
    index_list=[0, 94, 235, 17,
                61, 324, 55, 45,
                374, 65, 391, 488]
)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# =========================
# Generator setup
# =========================
# NOTE:
# - image_size and batch_size are defined in the "Speed / quality tuning" cell above.
# - Heavy ImageDataGenerator augmentation can be a major bottleneck (slow CPU image ops).
#   So we use LIGHT augmentation by default in FAST_MODE.

if AUGMENTATION_MODE == 'light':
    train_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=8,
        zoom_range=0.05,
        horizontal_flip=True,
        vertical_flip=False,
        fill_mode="nearest"
    )
elif AUGMENTATION_MODE == 'medium':
    train_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=10,
        brightness_range=(0.9, 1.1),
        width_shift_range=0.05,
        height_shift_range=0.05,
        zoom_range=0.10,
        horizontal_flip=True,
        vertical_flip=False,
        fill_mode="nearest"
    )
else:
    # Full / heavier augmentation (slower)
    train_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=10,
        brightness_range=(0.85, 1.15),
        width_shift_range=0.02,
        height_shift_range=0.02,
        shear_range=8.0,
        zoom_range=0.10,
        horizontal_flip=True,
        vertical_flip=False,
        fill_mode="nearest"
    )

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode="categorical",
    seed=SEED
)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=False,
    seed=SEED
)
# Out:
# Found 5600 images belonging to 4 classes.
# Found 1600 images belonging to 4 classes.

# %%
# =========================
# Class indices
# =========================
class_indices_train = train_generator.class_indices
class_indices_train_list = list(train_generator.class_indices.keys())

print("Categorical types for the training data:")
print(class_indices_train)
# Out:
# Categorical types for the training data:
# {'glioma': 0, 'meningioma': 1, 'notumor': 2, 'pituitary': 3}

# %%
# =========================
# Visualize augmentation
# =========================
def show_ImageDataGenerator(ImageDataGenerator, num_samples=5, figsize=(12, 12), save=False):
    """
    Function to viusalize how the ImageDataGenerator augments the data
    """
    _ = ImageDataGenerator  # kept for signature compatibility

    # Pull one augmented batch
    batch_x, batch_y = next(train_generator)
    images = batch_x[:num_samples]

    fig, axes = plt.subplots(1, num_samples, figsize=figsize)
    if num_samples == 1:
        axes = [axes]

    for i, ax in enumerate(axes):
        ax.imshow(images[i])
        ax.axis('off')

    plt.tight_layout()

    if save:
        plt.savefig('show_ImageDataGenerator.pdf')

    plt.show()

# %%
show_ImageDataGenerator(train_datagen, num_samples=5, figsize=(12.5, 8), save=SAVE)

# %% [markdown]
# ## Optimized EDA for the MRI Dataset
#
# This section consolidates the earlier exploratory analysis into a cleaner, reproducible pipeline with:
# - dataset-level summary tables,
# - balanced class visualizations,
# - image-shape and aspect-ratio analysis,
# - pixel intensity / entropy / edge-density analysis,
# - class-average MRI heatmaps,
# - 2D embedding plots for structure discovery.

# %%
# =========================
# Optimized EDA - imports and configuration
# =========================
from pathlib import Path
from PIL import Image
import cv2

from skimage.measure import shannon_entropy
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler

EDA_RANDOM_STATE = SEED
EDA_TARGET_SIZE = image_size
EDA_MAX_FILES_PER_CLASS = 250 if FAST_MODE else 400
EDA_EMBED_SIZE = (48, 48)
EDA_EMBED_SAMPLES_PER_CLASS = 80 if FAST_MODE else 120


def list_class_image_paths(data_dir, classes=None):
    """Return a mapping: class_name -> sorted image paths."""
    data_dir = Path(data_dir)
    classes = classes or sorted([p.name for p in data_dir.iterdir() if p.is_dir()])
    mapping = {}
    for cls in classes:
        class_dir = data_dir / cls
        if class_dir.is_dir():
            mapping[cls] = sorted([str(p) for p in class_dir.iterdir() if p.is_file()])
    return mapping


def load_rgb_image(img_path, target_size=None):
    img = Image.open(img_path).convert('RGB')
    if target_size is not None:
        img = img.resize(target_size)
    return np.asarray(img)


def load_gray_image(img_path, target_size=None):
    img = Image.open(img_path).convert('L')
    if target_size is not None:
        img = img.resize(target_size)
    return np.asarray(img)


def collect_image_metadata(data_dir, split_name, classes=None, max_files_per_class=None):
    """Build a tidy dataframe with image-level metadata and lightweight image statistics."""
    class_to_paths = list_class_image_paths(data_dir, classes=classes)
    rows = []

    for cls, paths in class_to_paths.items():
        selected_paths = paths[:max_files_per_class] if max_files_per_class else paths

        for img_path in selected_paths:
            try:
                gray = load_gray_image(img_path)
                h, w = gray.shape
                rows.append({
                    'split': split_name,
                    'class_name': cls,
                    'image_path': img_path,
                    'width': w,
                    'height': h,
                    'aspect_ratio': round(w / max(h, 1), 4),
                    'mean_intensity': float(gray.mean()),
                    'std_intensity': float(gray.std()),
                    'min_intensity': int(gray.min()),
                    'max_intensity': int(gray.max()),
                    'entropy': float(shannon_entropy(gray)),
                    'edge_density': float((cv2.Canny(gray, 80, 160) > 0).mean()),
                })
            except Exception:
                continue

    return pd.DataFrame(rows)


def build_split_summary(df):
    return (
        df.groupby(['split', 'class_name'])
          .agg(
              images=('image_path', 'count'),
              avg_width=('width', 'mean'),
              avg_height=('height', 'mean'),
              avg_intensity=('mean_intensity', 'mean'),
              avg_entropy=('entropy', 'mean'),
              avg_edge_density=('edge_density', 'mean'),
          )
          .round(2)
          .reset_index()
    )


def sample_paths_per_class(data_dir, classes=None, sample_per_class=40, seed=SEED):
    rng = random.Random(seed)
    class_to_paths = list_class_image_paths(data_dir, classes=classes)
    sampled_paths, sampled_labels = [], []

    for cls, paths in class_to_paths.items():
        if not paths:
            continue
        chosen = rng.sample(paths, min(sample_per_class, len(paths)))
        sampled_paths.extend(chosen)
        sampled_labels.extend([cls] * len(chosen))

    return sampled_paths, sampled_labels

# %%
# =========================
# Build train/test metadata tables
# =========================
train_meta_df = collect_image_metadata(
    train_dir,
    split_name='train',
    classes=CLASS_TYPES,
    max_files_per_class=EDA_MAX_FILES_PER_CLASS,
)

test_meta_df = collect_image_metadata(
    test_dir,
    split_name='test',
    classes=CLASS_TYPES,
    max_files_per_class=EDA_MAX_FILES_PER_CLASS,
)

eda_meta_df = pd.concat([train_meta_df, test_meta_df], ignore_index=True)
eda_summary_df = build_split_summary(eda_meta_df)

print(f'Train metadata rows: {len(train_meta_df):,}')
print(f'Test metadata rows : {len(test_meta_df):,}')
display(eda_summary_df)
# Out:
# Train metadata rows: 1,000
# Test metadata rows : 1,000
#    split  class_name  images  avg_width  avg_height  avg_intensity  \
# 0   test      glioma     250     486.80      491.01          40.48
# 1   test  meningioma     250     466.36      471.42          47.29
# 2   test     notumor     250     292.45      293.34          59.73
# 3   test   pituitary     250     506.88      506.88          49.28
# 4  train      glioma     250     512.00      512.00          34.04
# 5  train  meningioma     250     502.83      505.53          43.27
# 6  train     notumor     250     311.49      324.64          61.41
# 7  train   pituitary     250     523.23      522.33          49.85
#
#    avg_entropy  avg_edge_density
# 0         5.61              0.05
# 1         5.86              0.05
# 2         5.75              0.12
# 3         6.40              0.06
# 4         5.42              0.04
# 5         5.86              0.05
# 6         5.92              0.12
# 7         6.41              0.06

# %%
# =========================
# Dataset balance and split comparison
# =========================


fig, axes = plt.subplots(1, 2, figsize=(18, 6))

# ---- Absolute class distribution ----
sns.countplot(
    data=eda_meta_df,
    x="class_name",
    hue="split",
    order=CLASS_TYPES,
    ax=axes[0]
)

axes[0].set_title("Class Distribution by Split")
axes[0].set_xlabel("Tumor Type")
axes[0].set_ylabel("Number of Images")
axes[0].tick_params(axis="x", rotation=15)


# ---- Relative percentage distribution ----
count_df = (
    eda_meta_df
    .groupby(["split", "class_name"])
    .size()
    .reset_index(name="count")
)

count_df["percentage"] = (
    count_df.groupby("split")["count"]
    .transform(lambda x: x / x.sum() * 100)
)

sns.barplot(
    data=count_df,
    x="class_name",
    y="percentage",
    hue="split",
    order=CLASS_TYPES,
    ax=axes[1]
)

axes[1].set_title("Relative Class Share Within Each Split")
axes[1].set_xlabel("Tumor Type")
axes[1].set_ylabel("Percentage (%)")
axes[1].tick_params(axis="x", rotation=15)

plt.tight_layout()
plt.show()

# %%
# =========================
# Visual check: balanced random samples from each class
# =========================
def show_random_images_by_class(data_dir, classes, samples=5, seed=SEED, image_size=(160, 160)):
    rng = random.Random(seed)
    fig, axes = plt.subplots(len(classes), samples, figsize=(3 * samples, 3 * len(classes)))
    axes = np.array(axes, dtype=object)
    if len(classes) == 1:
        axes = axes.reshape(1, -1)

    for row, cls in enumerate(classes):
        class_dir = Path(data_dir) / cls
        paths = sorted([p for p in class_dir.iterdir() if p.is_file()])
        selected = rng.sample(paths, min(samples, len(paths)))

        for col in range(samples):
            ax = axes[row, col]
            if col < len(selected):
                img = load_rgb_image(str(selected[col]), target_size=image_size)
                ax.imshow(img)
                ax.set_title(f'{cls} #{col + 1}')
            ax.axis('off')

    plt.suptitle('Balanced Random MRI Samples by Class', fontsize=18, y=1.02)
    plt.tight_layout()
    plt.show()


show_random_images_by_class(train_dir, CLASS_TYPES, samples=5, seed=SEED)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# =========================
# Image dimension and aspect-ratio analysis
# =========================
fig, axes = plt.subplots(1, 3, figsize=(20, 5))

sns.histplot(data=train_meta_df, x='width', hue='class_name', kde=True, ax=axes[0], element='step')
axes[0].set_title('Image Width Distribution (Train)')

sns.histplot(data=train_meta_df, x='height', hue='class_name', kde=True, ax=axes[1], element='step')
axes[1].set_title('Image Height Distribution (Train)')

sns.boxplot(data=train_meta_df, x='class_name', y='aspect_ratio', order=CLASS_TYPES, ax=axes[2])
axes[2].set_title('Aspect Ratio by Class (Train)')
axes[2].tick_params(axis='x', rotation=15)

plt.tight_layout()
plt.show()

# %%
# =========================
# MRI intensity, entropy, and edge-structure analysis
# =========================
fig, axes = plt.subplots(2, 2, figsize=(18, 12))

sns.violinplot(
    data=train_meta_df,
    x='class_name', y='mean_intensity',
    order=CLASS_TYPES,
    inner='quartile',
    ax=axes[0, 0]
)
axes[0, 0].set_title('Mean Pixel Intensity by Class')
axes[0, 0].tick_params(axis='x', rotation=15)

sns.boxplot(
    data=train_meta_df,
    x='class_name', y='std_intensity',
    order=CLASS_TYPES,
    ax=axes[0, 1]
)
axes[0, 1].set_title('Contrast (Std Intensity) by Class')
axes[0, 1].tick_params(axis='x', rotation=15)

sns.boxplot(
    data=train_meta_df,
    x='class_name', y='entropy',
    order=CLASS_TYPES,
    ax=axes[1, 0]
)
axes[1, 0].set_title('Shannon Entropy by Class')
axes[1, 0].tick_params(axis='x', rotation=15)

sns.boxplot(
    data=train_meta_df,
    x='class_name', y='edge_density',
    order=CLASS_TYPES,
    ax=axes[1, 1]
)
axes[1, 1].set_title('Edge Density by Class')
axes[1, 1].tick_params(axis='x', rotation=15)

plt.tight_layout()
plt.show()

# %%
# =========================
# Class-average MRI maps and tumor-region overlays
# =========================
def plot_class_average_heatmaps(data_dir, classes=None, max_images_per_class=200, target_size=None, alpha=0.45):
    classes = classes or sorted([d for d in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, d))])
    target_size = target_size or EDA_TARGET_SIZE

    fig, axes = plt.subplots(len(classes), 3, figsize=(15, 4 * len(classes)))
    if len(classes) == 1:
        axes = np.expand_dims(axes, axis=0)

    for row, cls in enumerate(classes):
        class_dir = Path(data_dir) / cls
        img_files = sorted([p for p in class_dir.iterdir() if p.is_file()])[:max_images_per_class]

        stack = []
        for img_path in img_files:
            try:
                stack.append(load_gray_image(str(img_path), target_size=target_size).astype(np.float32))
            except Exception:
                continue

        if not stack:
            for col in range(3):
                axes[row, col].axis('off')
            continue

        stack = np.stack(stack, axis=0)
        mean_img = stack.mean(axis=0)
        zmap = (mean_img - mean_img.mean()) / (mean_img.std() + 1e-8)
        hotspot = np.maximum(zmap, 0.0)

        axes[row, 0].imshow(mean_img, cmap='gray')
        axes[row, 0].set_title(f'{cls.title()} — Mean MRI')
        axes[row, 0].axis('off')

        hm = axes[row, 1].imshow(hotspot, cmap='hot')
        axes[row, 1].set_title(f'{cls.title()} — High-Activation Regions')
        axes[row, 1].axis('off')
        fig.colorbar(hm, ax=axes[row, 1], fraction=0.046, pad=0.04)

        axes[row, 2].imshow(mean_img, cmap='gray')
        axes[row, 2].imshow(hotspot, cmap='jet', alpha=alpha)
        axes[row, 2].set_title(f'{cls.title()} — Overlay View')
        axes[row, 2].axis('off')

    plt.suptitle('Class-Average MRI Heatmaps', fontsize=18, y=1.01)
    plt.tight_layout()
    plt.show()


plot_class_average_heatmaps(
    train_dir,
    classes=CLASS_TYPES,
    max_images_per_class=EDA_MAX_FILES_PER_CLASS,
    target_size=EDA_TARGET_SIZE,
    alpha=0.40,
)

# %%
# =========================
# 2D embedding of MRI images (PCA + t-SNE)
# =========================
def build_embedding_dataframe(data_dir, classes, sample_per_class=80, resize_to=(48, 48), seed=SEED):
    sampled_paths, sampled_labels = sample_paths_per_class(
        data_dir,
        classes=classes,
        sample_per_class=sample_per_class,
        seed=seed,
    )

    flattened = []
    for img_path in sampled_paths:
        gray = load_gray_image(img_path, target_size=resize_to).astype(np.float32) / 255.0
        flattened.append(gray.reshape(-1))

    X = np.asarray(flattened)
    y = np.asarray(sampled_labels)
    return X, y


X_embed, y_embed = build_embedding_dataframe(
    train_dir,
    classes=CLASS_TYPES,
    sample_per_class=EDA_EMBED_SAMPLES_PER_CLASS,
    resize_to=EDA_EMBED_SIZE,
    seed=EDA_RANDOM_STATE,
)

X_scaled = StandardScaler().fit_transform(X_embed)
X_pca = PCA(n_components=2, random_state=EDA_RANDOM_STATE).fit_transform(X_scaled)
X_tsne = TSNE(
    n_components=2,
    perplexity=min(30, max(5, len(X_scaled) // 12)),
    init='pca',
    learning_rate='auto',
    random_state=EDA_RANDOM_STATE,
).fit_transform(X_scaled)

embed_df = pd.DataFrame({
    'class_name': y_embed,
    'pca_1': X_pca[:, 0],
    'pca_2': X_pca[:, 1],
    'tsne_1': X_tsne[:, 0],
    'tsne_2': X_tsne[:, 1],
})

fig, axes = plt.subplots(1, 2, figsize=(18, 7))

sns.scatterplot(data=embed_df, x='pca_1', y='pca_2', hue='class_name', hue_order=CLASS_TYPES, ax=axes[0], s=55)
axes[0].set_title('PCA Projection of MRI Samples')

sns.scatterplot(data=embed_df, x='tsne_1', y='tsne_2', hue='class_name', hue_order=CLASS_TYPES, ax=axes[1], s=55)
axes[1].set_title('t-SNE Projection of MRI Samples')

plt.tight_layout()
plt.show()

# %%
# =========================
# Training configuration
# =========================
image_shape = (image_size[0], image_size[1], 3)

# EPOCHS_HEAD / EPOCHS_FINE are defined in the tuning cell.
# FINE_TUNE and FINE_TUNE_FRACTION are also defined there.

steps_per_epoch = max(1, train_generator.samples // batch_size)
validation_steps = max(1, test_generator.samples // batch_size)

print(f'Image shape: {image_shape}')
print(f'Batch size: {batch_size}')
print(f'Steps Per Epoch: {steps_per_epoch}')
print(f'Validation steps: {validation_steps}')

print('EPOCHS_HEAD:', EPOCHS_HEAD)
print('EPOCHS_FINE:', EPOCHS_FINE)
print('FINE_TUNE:', FINE_TUNE)
print('FINE_TUNE_FRACTION:', FINE_TUNE_FRACTION)
print('LR_HEAD:', LR_HEAD)
print('LR_FINE:', LR_FINE)
# Out:
# Image shape: (128, 128, 3)
# Batch size: 64
# Steps Per Epoch: 87
# Validation steps: 25
# EPOCHS_HEAD: 4
# EPOCHS_FINE: 2
# FINE_TUNE: True
# FINE_TUNE_FRACTION: 0.1
# LR_HEAD: 0.0003
# LR_FINE: 0.0001

# %%
# =========================
# Output Images and Labels Visualization
# =========================
def plot_sample_predictions(model, test_generator, categories, test_dir, num_samples=9, figsize=(12, 8)):
    """
    Nice display of prediction samples to see CNN predictions
    for classification.
    """
    _ = test_dir  # kept for signature compatibility

    # Ensure generator starts from beginning
    try:
        test_generator.reset()
    except Exception:
        pass

    predictions = model.predict(test_generator, verbose=0)
    predicted_categories = np.argmax(predictions, axis=1)
    true_categories = test_generator.classes

    test_images = np.array(test_generator.filepaths)
    sample_indices = np.random.choice(len(test_images), size=num_samples, replace=False)

    sample_images = test_images[sample_indices]
    sample_predictions = [categories[predicted_categories[i]] for i in sample_indices]
    sample_true_labels = [categories[true_categories[i]] for i in sample_indices]

    plt.figure(figsize=figsize)

    grid = int(np.ceil(np.sqrt(num_samples)))
    for i, image_path in enumerate(sample_images):
        plt.subplot(grid, grid, i + 1)
        img = plt.imread(image_path)
        plt.imshow(img)
        plt.axis("off")

        prediction_color = 'green' if sample_predictions[i] == sample_true_labels[i] else 'red'
        plt.title(f"Predicted: {sample_predictions[i]}\nTrue: {sample_true_labels[i]}", color=prediction_color)

    plt.tight_layout()
    plt.show()


# =========================
# Confusion matrix
# =========================
def CM(CNN_model, test_generator, categories):
    """
    Function to return the confusion matrix of a given CNN model.
    """
    _ = categories  # kept for signature compatibility
    from sklearn.metrics import confusion_matrix

    try:
        test_generator.reset()
    except Exception:
        pass

    predictions = CNN_model.predict(test_generator, verbose=0)
    predicted_categories = np.argmax(predictions, axis=1)
    true_categories = test_generator.classes

    confusion_matrix_array = confusion_matrix(true_categories, predicted_categories)
    return confusion_matrix_array


# =========================
# Metric Analysis
# =========================
def calculate_metrics(confusion_matrix, categories):
    """
    Function to calculate important metrics for multi-classification problems.
    """
    cm = confusion_matrix.astype(np.float64)

    # Prevent divide-by-zero warnings
    eps = 1e-12
    precision = np.diag(cm) / (np.sum(cm, axis=0) + eps)
    recall    = np.diag(cm) / (np.sum(cm, axis=1) + eps)
    f1_score  = 2 * (precision * recall) / (precision + recall + eps)
    accuracy  = np.sum(np.diag(cm)) / (np.sum(cm) + eps)

    for i, category in enumerate(categories):
        print(f"Class: {category.title()}")
        print(f"Precision: {precision[i]:.3f}")
        print(f"Recall: {recall[i]:.3f}")
        print(f"F1-Score: {f1_score[i]:.3f}\n")

    print(f"\nAccuracy: {accuracy:.3f}")

# %%
# =========================
# Helper functions for the three selected models
# =========================
def compile_model(model, lr=1e-3):
    """Compile with categorical crossentropy + accuracy (Keras 3 compatible)."""
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    loss_fn = tf.keras.losses.CategoricalCrossentropy(label_smoothing=LABEL_SMOOTHING)
    model.compile(optimizer=optimizer, loss=loss_fn, metrics=['accuracy'])
    return model

def get_callbacks(model_name):
    """Common callbacks (early stop + reduce LR + best checkpoint).
    Patience values are controlled by EARLY_STOP_PATIENCE / REDUCE_LR_PATIENCE in the tuning cell.
    """
    safe_name = model_name.replace(" ", "_").replace("/", "_").replace("(", "").replace(")", "")
    return [
        EarlyStopping(
            monitor='val_loss',
            patience=EARLY_STOP_PATIENCE,
            min_delta=1e-4,
            restore_best_weights=True,
            verbose=1
        ),
        ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.3,
            patience=REDUCE_LR_PATIENCE,
            min_delta=1e-4,
            verbose=1
        ),
        ModelCheckpoint(
            filepath=f"{safe_name}_best.keras",
            monitor='val_accuracy',
            mode='max',
            save_best_only=True,
            verbose=1
        )
    ]

def merge_histories(history_head, history_fine=None):
    """Merge two Keras History objects into a single dict for plotting."""
    out = {}
    if history_head is None:
        return out
    for k, v in history_head.history.items():
        out[k] = list(v)

    if history_fine is not None:
        for k, v in history_fine.history.items():
            out[k] = out.get(k, []) + list(v)
    return out

def plot_training_curves(history_dict, model_title):
    """Plot accuracy/loss curves."""
    if not history_dict:
        print("No history to plot.")
        return

    fig, ax = plt.subplots(ncols=2, figsize=(15, 6))

    if 'accuracy' in history_dict and 'val_accuracy' in history_dict:
        ax[0].plot(history_dict['accuracy'])
        ax[0].plot(history_dict['val_accuracy'])
        ax[0].set_title(f'{model_title} — Accuracy')
        ax[0].set_xlabel('Epoch')
        ax[0].set_ylabel('Accuracy')
        ax[0].legend(['Train', 'Validation'])
        ax[0].grid(alpha=0.2)

    if 'loss' in history_dict and 'val_loss' in history_dict:
        ax[1].plot(history_dict['loss'])
        ax[1].plot(history_dict['val_loss'])
        ax[1].set_title(f'{model_title} — Loss')
        ax[1].set_xlabel('Epoch')
        ax[1].set_ylabel('Loss')
        ax[1].legend(['Train', 'Validation'])
        ax[1].grid(alpha=0.2)

    plt.show()

def get_predictions(model, generator):
    """Get y_true, y_pred, y_prob for a generator (assumes shuffle=False for test generator)."""
    try:
        generator.reset()
    except Exception:
        pass

    y_prob = model.predict(generator, verbose=0)
    y_pred = np.argmax(y_prob, axis=1)
    y_true = generator.classes
    return y_true, y_pred, y_prob

def plot_confusion_matrices(y_true, y_pred, class_names, model_title):
    """Plot raw and normalized confusion matrices."""
    cm = confusion_matrix(y_true, y_pred)

    # Raw
    plt.figure(figsize=(8, 7))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False,
                xticklabels=[c.title() for c in class_names],
                yticklabels=[c.title() for c in class_names])
    plt.title(f"{model_title} — Confusion Matrix (Counts)")
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.show()

    # Normalized
    cmn = cm.astype(np.float64) / np.maximum(cm.sum(axis=1, keepdims=True), 1e-12)
    plt.figure(figsize=(8, 7))
    sns.heatmap(cmn, annot=True, fmt=".2f", cmap="Blues", cbar=False,
                xticklabels=[c.title() for c in class_names],
                yticklabels=[c.title() for c in class_names])
    plt.title(f"{model_title} — Confusion Matrix (Normalized)")
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.show()

    return cm

def plot_classification_report_heatmap(y_true, y_pred, class_names, model_title):
    """Print and plot classification report."""
    report = classification_report(y_true, y_pred, target_names=class_names, output_dict=True)
    df = pd.DataFrame(report).transpose()
    display(df)

    # heatmap for per-class rows only
    per_class = df.iloc[:len(class_names)][['precision', 'recall', 'f1-score']]
    plt.figure(figsize=(8, 4))
    sns.heatmap(per_class, annot=True, fmt=".3f", cmap="viridis", cbar=True)
    plt.title(f"{model_title} — Classification Report (per class)")
    plt.show()

def plot_roc_curves(y_true, y_prob, class_names, model_title):
    """One-vs-rest ROC curves for multiclass."""
    y_true_oh = tf.keras.utils.to_categorical(y_true, num_classes=len(class_names))

    plt.figure(figsize=(9, 7))
    for i, name in enumerate(class_names):
        fpr, tpr, _ = roc_curve(y_true_oh[:, i], y_prob[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f"{name} (AUC={roc_auc:.3f})")

    # Micro-average
    fpr_micro, tpr_micro, _ = roc_curve(y_true_oh.ravel(), y_prob.ravel())
    auc_micro = auc(fpr_micro, tpr_micro)
    plt.plot(fpr_micro, tpr_micro, linestyle='--', label=f"micro-average (AUC={auc_micro:.3f})")

    plt.plot([0, 1], [0, 1], linestyle=':')
    plt.title(f"{model_title} — ROC Curves")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.legend()
    plt.grid(alpha=0.2)
    plt.show()

def plot_precision_recall_curves(y_true, y_prob, class_names, model_title):
    """One-vs-rest Precision-Recall curves for multiclass."""
    y_true_oh = tf.keras.utils.to_categorical(y_true, num_classes=len(class_names))

    plt.figure(figsize=(9, 7))
    for i, name in enumerate(class_names):
        precision, recall, _ = precision_recall_curve(y_true_oh[:, i], y_prob[:, i])
        ap = average_precision_score(y_true_oh[:, i], y_prob[:, i])
        plt.plot(recall, precision, label=f"{name} (AP={ap:.3f})")

    ap_micro = average_precision_score(y_true_oh, y_prob, average='micro')
    plt.title(f"{model_title} — Precision-Recall Curves (micro-AP={ap_micro:.3f})")
    plt.xlabel("Recall")
    plt.ylabel("Precision")
    plt.legend()
    plt.grid(alpha=0.2)
    plt.show()

def fine_tune_base_model(model, base_model, fine_tune_fraction=0.2, lr=1e-4):
    """Unfreeze last fraction of layers for fine-tuning.
    Also keeps BatchNorm layers frozen for stability (recommended).
    """
    if base_model is None:
        return None

    base_model.trainable = True
    fine_tune_at = int(len(base_model.layers) * (1 - fine_tune_fraction))

    # Freeze early layers
    for layer in base_model.layers[:fine_tune_at]:
        layer.trainable = False

    # Keep BatchNorm frozen in the unfrozen part too (stability + often faster)
    for layer in base_model.layers[fine_tune_at:]:
        if isinstance(layer, tf.keras.layers.BatchNormalization):
            layer.trainable = False

    compile_model(model, lr=lr)
    print(f"Fine-tuning from layer {fine_tune_at} / {len(base_model.layers)} (unfroze last {fine_tune_fraction:.0%})")
    return fine_tune_at

# Collect results here
results = {}

# %%
# =========================
# Model builders
# Each builder returns: (model, base_model_or_None)
# =========================
def build_xception_model(input_shape, n_classes):
    preprocess = tf.keras.applications.xception.preprocess_input
    base = tf.keras.applications.Xception(
        include_top=False, weights='imagenet', input_shape=input_shape
    )
    base.trainable = False

    inputs = tf.keras.Input(shape=input_shape)
    # generator yields [0,1] (rescale=1/255). Most preprocess_input expect [0,255].
    x = tf.keras.layers.Lambda(lambda t: preprocess(t * 255.0), name="xception_preprocess")(inputs)
    x = base(x, training=False)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dropout(0.30, seed=SEED)(x)
    outputs = tf.keras.layers.Dense(n_classes, activation='softmax', dtype='float32')(x)
    model = tf.keras.Model(inputs, outputs, name="Xception")
    return model, base

def build_efficientnetb0_model(input_shape, n_classes):
    preprocess = tf.keras.applications.efficientnet.preprocess_input
    base = tf.keras.applications.EfficientNetB0(
        include_top=False, weights='imagenet', input_shape=input_shape
    )
    base.trainable = False

    inputs = tf.keras.Input(shape=input_shape)
    x = tf.keras.layers.Lambda(lambda t: preprocess(t * 255.0), name="efficientnet_preprocess")(inputs)
    x = base(x, training=False)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dropout(0.30, seed=SEED)(x)
    outputs = tf.keras.layers.Dense(n_classes, activation='softmax', dtype='float32')(x)
    model = tf.keras.Model(inputs, outputs, name="EfficientNetB0")
    return model, base

def build_resnet50_model(input_shape, n_classes):
    preprocess = tf.keras.applications.resnet50.preprocess_input
    base = tf.keras.applications.ResNet50(
        include_top=False, weights='imagenet', input_shape=input_shape
    )
    base.trainable = False

    inputs = tf.keras.Input(shape=input_shape)
    x = tf.keras.layers.Lambda(lambda t: preprocess(t * 255.0), name="resnet50_preprocess")(inputs)
    x = base(x, training=False)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dropout(0.30, seed=SEED)(x)
    outputs = tf.keras.layers.Dense(n_classes, activation='softmax', dtype='float32')(x)
    model = tf.keras.Model(inputs, outputs, name="ResNet50")
    return model, base

# %%
# =========================
# Misclassified images
# =========================
def visualize_misclassified_images(model, test_generator, class_indices):
    """
    Visualize misclassified images from the test set alongside their predicted and true labels.
    """
    from tensorflow.keras.preprocessing.image import array_to_img

    # ensure stable iteration
    try:
        test_generator.reset()
    except Exception:
        pass

    misclassified_images = []
    misclassified_labels_true = []
    misclassified_labels_pred = []

    # Use index-based access to avoid exhausting the generator unpredictably
    for i in range(len(test_generator)):
        batch_images, batch_labels = test_generator[i]
        batch_predictions = model.predict(batch_images, verbose=0)

        predicted_labels = [list(class_indices.keys())[np.argmax(pred)] for pred in batch_predictions]
        true_labels = [list(class_indices.keys())[np.argmax(lab)] for lab in batch_labels]

        for j in range(len(batch_images)):
            if predicted_labels[j] != true_labels[j]:
                misclassified_images.append(batch_images[j])
                misclassified_labels_true.append(true_labels[j])
                misclassified_labels_pred.append(predicted_labels[j])

    num_misclassified = len(misclassified_images)
    print("Misclassified images found:", num_misclassified)

    if num_misclassified == 0:
        print("No misclassifications to display.")
        return

    # Show at most 24 misclassified images to keep the plot readable
    max_show = min(24, num_misclassified)
    num_rows = int(np.ceil(max_show / 4))
    plt.figure(figsize=(12, 3 * num_rows))

    for k in range(max_show):
        plt.subplot(num_rows, 4, k + 1)
        plt.title(
            f"True: {misclassified_labels_true[k]}\nPred: {misclassified_labels_pred[k]}",
            color='red'
        )
        plt.imshow(array_to_img(misclassified_images[k]))
        plt.axis('off')

    plt.tight_layout()
    plt.show()

    # reset again for safety
    try:
        test_generator.reset()
    except Exception:
        pass

# %%
# =========================
# Evaluate + plot wrapper (used by every model)
# =========================
def evaluate_and_plot(model, history_dict, model_title):
    # Curves
    plot_training_curves(history_dict, model_title)

    # Evaluation
    try:
        test_generator.reset()
    except Exception:
        pass

    loss, acc = model.evaluate(test_generator, verbose=0)
    print(f"{model_title} — Test Loss: {loss:.5f}")
    print(f"{model_title} — Test Accuracy: {acc:.5f}")

    # Predictions for graphs
    y_true, y_pred, y_prob = get_predictions(model, test_generator)

    # Confusion matrix (counts + normalized)
    cm = plot_confusion_matrices(y_true, y_pred, class_indices_train_list, model_title)

    # Printed metrics (your baseline function)
    calculate_metrics(cm, categories=class_indices_train_list)

    # Classification report (extra)
    plot_classification_report_heatmap(y_true, y_pred, class_indices_train_list, model_title)

    # ROC + PR curves (optional extra)
    if 'PLOT_EXTRA_GRAPHS' in globals() and PLOT_EXTRA_GRAPHS:
        plot_roc_curves(y_true, y_prob, class_indices_train_list, model_title)
        plot_precision_recall_curves(y_true, y_prob, class_indices_train_list, model_title)

    # Sample predictions & misclassified images (baseline functions)
    plot_sample_predictions(
        model=model,
        test_generator=test_generator,
        categories=class_indices_train_list,
        test_dir=test_dir,
        num_samples=9,
        figsize=(13, 12)
    )

    visualize_misclassified_images(model, test_generator, test_generator.class_indices)

    return {"loss": float(loss), "accuracy": float(acc)}

# %% [markdown]
# ## Model 1: Xception (Baseline)

# %%
# =========================
# Build + compile — Xception (Baseline)
# =========================
tf.keras.backend.clear_session()
gc.collect()

MODEL_NAME_1 = "Xception (Baseline)"

model_1, base_1 = build_xception_model(image_shape, N_TYPES)
compile_model(model_1, lr=LR_HEAD)
model_1.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "Xception"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ xception_preprocess (Lambda)    │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ xception (Functional)           │ (None, 4, 4, 2048)     │    20,861,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 4)              │         8,196 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,869,676 (79.61 MB)
#  Trainable params: 8,196 (32.02 KB)
#  Non-trainable params: 20,861,480 (79.58 MB)

# %%
# =========================
# Train — Xception (Baseline)
# =========================
callbacks_1 = get_callbacks(MODEL_NAME_1)

# Reset generators before training (good practice)
try:
    train_generator.reset()
    test_generator.reset()
except Exception:
    pass

t0 = time.time()
history_1_head = model_1.fit(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    epochs=EPOCHS_HEAD,
    validation_data=test_generator,
    validation_steps=validation_steps,
    callbacks=callbacks_1
)
t1 = time.time()
print(f"Xception (Baseline) head training time: {(t1 - t0)/60:.2f} min")

history_1_fine = None
if FINE_TUNE and base_1 is not None:
    # Fine-tune the last fraction of the backbone
    fine_tune_base_model(model_1, base_1, fine_tune_fraction=FINE_TUNE_FRACTION, lr=LR_FINE)

    t2 = time.time()
    history_1_fine = model_1.fit(
        train_generator,
        steps_per_epoch=steps_per_epoch,
        epochs=EPOCHS_FINE,
        validation_data=test_generator,
        validation_steps=validation_steps,
        callbacks=callbacks_1
    )
    t3 = time.time()
    print(f"Xception (Baseline) fine-tuning time: {(t3 - t2)/60:.2f} min")
# Out:
# Epoch 1/4
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 623ms/step - accuracy: 0.4708 - loss: 1.2208
# Epoch 1: val_accuracy improved from None to 0.71500, saving model to Xception_Baseline_best.keras
#
# Epoch 1: finished saving model to Xception_Baseline_best.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 204s 2s/step - accuracy: 0.5766 - loss: 1.0557 - val_accuracy: 0.7150 - val_loss: 0.8120 - learning_rate: 3.0000e-04
# Epoch 2/4
#  1/87 ━━━━━━━━━━━━━━━━━━━━ 44s 514ms/step - accuracy: 0.7188 - loss: 0.7607
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 2: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
#
# Epoch 2: val_accuracy did not improve from 0.71500
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 9s 102ms/step - accuracy: 0.7188 - loss: 0.7607 - val_accuracy: 0.7138 - val_loss: 0.8122 - learning_rate: 3.0000e-04
# Epoch 3/4
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - accuracy: 0.7138 - loss: 0.8030
# Epoch 3: val_accuracy improved from 0.71500 to 0.73813, saving model to Xception_Baseline_best.keras
#
# Epoch 3: finished saving model to Xception_Baseline_best.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 61s 697ms/step - accuracy: 0.7189 - loss: 0.8040 - val_accuracy: 0.7381 - val_loss: 0.7824 - learning_rate: 9.0000e-05
# Epoch 4/4
#  1/87 ━━━━━━━━━━━━━━━━━━━━ 1:07 789ms/step - accuracy: 0.7812 - loss: 0.6568
# Epoch 4: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
#
# Epoch 4: val_accuracy did not improve from 0.73813
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - accuracy: 0.7812 - loss: 0.6568 - val_accuracy: 0.7375 - val_loss: 0.7824 - learning_rate: 9.0000e-05
# Restoring model weights from the end of the best epoch: 3.
# Xception (Baseline) head training time: 4.73 min
# Fine-tuning from layer 118 / 132 (unfroze last 10%)
# Epoch 1/2
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 614ms/step - accuracy: 0.8001 - loss: 0.6484
# Epoch 1: val_accuracy improved from 0.73813 to 0.82875, saving model to Xception_Baseline_best.keras
#
# Epoch 1: finished saving model to Xception_Baseline_best.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 70s 747ms/step - accuracy: 0.8378 - loss: 0.5716 - val_accuracy: 0.8288 - val_loss: 0.6319 - learning_rate: 1.0000e-04
# Epoch 2/2
#  1/87 ━━━━━━━━━━━━━━━━━━━━ 1:05 764ms/step - accuracy: 0.8906 - loss: 0.4855
# Epoch 2: val_accuracy improved from 0.82875 to 0.82938, saving model to Xception_Baseline_best.keras
#
# Epoch 2: finished saving model to Xception_Baseline_best.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 10s 110ms/step - accuracy: 0.8906 - loss: 0.4855 - val_accuracy: 0.8294 - val_loss: 0.6255 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 2.
# Xception (Baseline) fine-tuning time: 1.35 min

# %%
# =========================
# Evaluate + graphs — Xception (Baseline)
# =========================
history_1 = merge_histories(history_1_head, history_1_fine)

metrics_1 = evaluate_and_plot(model_1, history_1, MODEL_NAME_1)
results[MODEL_NAME_1] = metrics_1
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Model 3: EfficientNetB0

# %%
# =========================
# Build + compile — EfficientNetB0
# =========================
tf.keras.backend.clear_session()
gc.collect()

MODEL_NAME_3 = "EfficientNetB0"

model_3, base_3 = build_efficientnetb0_model(image_shape, N_TYPES)
compile_model(model_3, lr=LR_HEAD)
model_3.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "EfficientNetB0"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnet_preprocess         │ (None, 128, 128, 3)    │             0 │
# │ (Lambda)                        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 4, 4, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 4)              │         5,124 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,054,695 (15.47 MB)
#  Trainable params: 5,124 (20.02 KB)
#  Non-trainable params: 4,049,571 (15.45 MB)

# %%
# =========================
# Train — EfficientNetB0
# =========================
callbacks_3 = get_callbacks(MODEL_NAME_3)

# Reset generators before training (good practice)
try:
    train_generator.reset()
    test_generator.reset()
except Exception:
    pass

t0 = time.time()
history_3_head = model_3.fit(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    epochs=EPOCHS_HEAD,
    validation_data=test_generator,
    validation_steps=validation_steps,
    callbacks=callbacks_3
)
t1 = time.time()
print(f"EfficientNetB0 head training time: {(t1 - t0)/60:.2f} min")

history_3_fine = None
if FINE_TUNE and base_3 is not None:
    # Fine-tune the last fraction of the backbone
    fine_tune_base_model(model_3, base_3, fine_tune_fraction=FINE_TUNE_FRACTION, lr=LR_FINE)

    t2 = time.time()
    history_3_fine = model_3.fit(
        train_generator,
        steps_per_epoch=steps_per_epoch,
        epochs=EPOCHS_FINE,
        validation_data=test_generator,
        validation_steps=validation_steps,
        callbacks=callbacks_3
    )
    t3 = time.time()
    print(f"EfficientNetB0 fine-tuning time: {(t3 - t2)/60:.2f} min")
# Out:
# Epoch 1/4
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 561ms/step - accuracy: 0.3596 - loss: 1.3806
# Epoch 1: val_accuracy improved from None to 0.67313, saving model to EfficientNetB0_best.keras
#
# Epoch 1: finished saving model to EfficientNetB0_best.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 71s 704ms/step - accuracy: 0.4886 - loss: 1.1964 - val_accuracy: 0.6731 - val_loss: 0.9250 - learning_rate: 3.0000e-04
# Epoch 2/4
#  1/87 ━━━━━━━━━━━━━━━━━━━━ 44s 521ms/step - accuracy: 0.5938 - loss: 1.0104
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 2: val_accuracy did not improve from 0.67313
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 9s 95ms/step - accuracy: 0.5938 - loss: 1.0104 - val_accuracy: 0.6731 - val_loss: 0.9232 - learning_rate: 3.0000e-04
# Epoch 3/4
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - accuracy: 0.7007 - loss: 0.8864
# Epoch 3: val_accuracy improved from 0.67313 to 0.71500, saving model to EfficientNetB0_best.keras
#
# Epoch 3: finished saving model to EfficientNetB0_best.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 58s 670ms/step - accuracy: 0.7128 - loss: 0.8516 - val_accuracy: 0.7150 - val_loss: 0.8153 - learning_rate: 3.0000e-04
# Epoch 4/4
#  1/87 ━━━━━━━━━━━━━━━━━━━━ 47s 556ms/step - accuracy: 0.7969 - loss: 0.6904
# Epoch 4: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
#
# Epoch 4: val_accuracy improved from 0.71500 to 0.71562, saving model to EfficientNetB0_best.keras
#
# Epoch 4: finished saving model to EfficientNetB0_best.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 10s 106ms/step - accuracy: 0.7969 - loss: 0.6904 - val_accuracy: 0.7156 - val_loss: 0.8166 - learning_rate: 3.0000e-04
# Restoring model weights from the end of the best epoch: 3.
# EfficientNetB0 head training time: 2.48 min
# Fine-tuning from layer 214 / 238 (unfroze last 10%)
# Epoch 1/2
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 582ms/step - accuracy: 0.7831 - loss: 0.6772
# Epoch 1: val_accuracy improved from 0.71562 to 0.75563, saving model to EfficientNetB0_best.keras
#
# Epoch 1: finished saving model to EfficientNetB0_best.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 74s 723ms/step - accuracy: 0.8053 - loss: 0.6241 - val_accuracy: 0.7556 - val_loss: 0.7587 - learning_rate: 1.0000e-04
# Epoch 2/2
#  1/87 ━━━━━━━━━━━━━━━━━━━━ 49s 576ms/step - accuracy: 0.8906 - loss: 0.5273
# Epoch 2: val_accuracy improved from 0.75563 to 0.76250, saving model to EfficientNetB0_best.keras
#
# Epoch 2: finished saving model to EfficientNetB0_best.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - accuracy: 0.8906 - loss: 0.5273 - val_accuracy: 0.7625 - val_loss: 0.7395 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 2.
# EfficientNetB0 fine-tuning time: 1.40 min

# %%
# =========================
# Evaluate + graphs — EfficientNetB0
# =========================
history_3 = merge_histories(history_3_head, history_3_fine)

metrics_3 = evaluate_and_plot(model_3, history_3, MODEL_NAME_3)
results[MODEL_NAME_3] = metrics_3
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Model 4: ResNet50

# %%
# =========================
# Build + compile — ResNet50
# =========================
tf.keras.backend.clear_session()
gc.collect()

MODEL_NAME_4 = "ResNet50"

model_4, base_4 = build_resnet50_model(image_shape, N_TYPES)
compile_model(model_4, lr=LR_HEAD)
model_4.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "ResNet50"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50_preprocess (Lambda)    │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 4, 4, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 4)              │         8,196 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,595,908 (90.01 MB)
#  Trainable params: 8,196 (32.02 KB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %%
# =========================
# Train — ResNet50
# =========================
callbacks_4 = get_callbacks(MODEL_NAME_4)

# Reset generators before training (good practice)
try:
    train_generator.reset()
    test_generator.reset()
except Exception:
    pass

t0 = time.time()
history_4_head = model_4.fit(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    epochs=EPOCHS_HEAD,
    validation_data=test_generator,
    validation_steps=validation_steps,
    callbacks=callbacks_4
)
t1 = time.time()
print(f"ResNet50 head training time: {(t1 - t0)/60:.2f} min")

history_4_fine = None
if FINE_TUNE and base_4 is not None:
    # Fine-tune the last fraction of the backbone
    fine_tune_base_model(model_4, base_4, fine_tune_fraction=FINE_TUNE_FRACTION, lr=LR_FINE)

    t2 = time.time()
    history_4_fine = model_4.fit(
        train_generator,
        steps_per_epoch=steps_per_epoch,
        epochs=EPOCHS_FINE,
        validation_data=test_generator,
        validation_steps=validation_steps,
        callbacks=callbacks_4
    )
    t3 = time.time()
    print(f"ResNet50 fine-tuning time: {(t3 - t2)/60:.2f} min")
# Out:
# Epoch 1/4
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 638ms/step - accuracy: 0.4238 - loss: 1.5436
# Epoch 1: val_accuracy improved from None to 0.71938, saving model to ResNet50_best.keras
#
# Epoch 1: finished saving model to ResNet50_best.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 76s 787ms/step - accuracy: 0.5423 - loss: 1.2198 - val_accuracy: 0.7194 - val_loss: 0.8893 - learning_rate: 3.0000e-04
# Epoch 2/4
#  1/87 ━━━━━━━━━━━━━━━━━━━━ 1:39 1s/step - accuracy: 0.6719 - loss: 0.9248
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 2: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
#
# Epoch 2: val_accuracy improved from 0.71938 to 0.72062, saving model to ResNet50_best.keras
#
# Epoch 2: finished saving model to ResNet50_best.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 10s 107ms/step - accuracy: 0.6719 - loss: 0.9248 - val_accuracy: 0.7206 - val_loss: 0.8899 - learning_rate: 3.0000e-04
# Epoch 3/4
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 624ms/step - accuracy: 0.7173 - loss: 0.8271
# Epoch 3: val_accuracy improved from 0.72062 to 0.73813, saving model to ResNet50_best.keras
#
# Epoch 3: finished saving model to ResNet50_best.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 65s 740ms/step - accuracy: 0.7209 - loss: 0.8224 - val_accuracy: 0.7381 - val_loss: 0.8454 - learning_rate: 9.0000e-05
# Epoch 4/4
#  1/87 ━━━━━━━━━━━━━━━━━━━━ 1:03 742ms/step - accuracy: 0.7344 - loss: 0.8122
# Epoch 4: val_accuracy improved from 0.73813 to 0.73875, saving model to ResNet50_best.keras
#
# Epoch 4: finished saving model to ResNet50_best.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 10s 105ms/step - accuracy: 0.7344 - loss: 0.8122 - val_accuracy: 0.7387 - val_loss: 0.8440 - learning_rate: 9.0000e-05
# Restoring model weights from the end of the best epoch: 4.
# ResNet50 head training time: 2.70 min
# Fine-tuning from layer 157 / 175 (unfroze last 10%)
# Epoch 1/2
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 629ms/step - accuracy: 0.7830 - loss: 0.6707
# Epoch 1: val_accuracy improved from 0.73875 to 0.85875, saving model to ResNet50_best.keras
#
# Epoch 1: finished saving model to ResNet50_best.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 76s 781ms/step - accuracy: 0.8401 - loss: 0.5642 - val_accuracy: 0.8587 - val_loss: 0.5714 - learning_rate: 1.0000e-04
# Epoch 2/2
#  1/87 ━━━━━━━━━━━━━━━━━━━━ 51s 602ms/step - accuracy: 0.9062 - loss: 0.5019
# Epoch 2: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
#
# Epoch 2: val_accuracy improved from 0.85875 to 0.86063, saving model to ResNet50_best.keras
#
# Epoch 2: finished saving model to ResNet50_best.keras
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 130ms/step - accuracy: 0.9062 - loss: 0.5019 - val_accuracy: 0.8606 - val_loss: 0.5770 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 1.
# ResNet50 fine-tuning time: 1.49 min

# %%
# =========================
# Evaluate + graphs — ResNet50
# =========================
history_4 = merge_histories(history_4_head, history_4_fine)

metrics_4 = evaluate_and_plot(model_4, history_4, MODEL_NAME_4)
results[MODEL_NAME_4] = metrics_4
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Summary of results

# %%
# =========================
# Summary table
# =========================
if results:
    summary_df = pd.DataFrame(results).T.sort_values("accuracy", ascending=False)
    display(summary_df)
else:
    print("No results yet. Run model cells above.")
# Out:
#                          loss  accuracy
# ResNet50             0.571409  0.858750
# Xception (Baseline)  0.625487  0.829375
# EfficientNetB0       0.739530  0.762500
